# %%
import torch 
import gymnasium as gym
from stable_baselines3 import A2C
import wandb
import tensorboard
import panda_gym

# %%
wandb.init(project="a2c_training", sync_tensorboard=True)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# /usr/lib/python3/dist-packages/requests/__init__.py:87: RequestsDependencyWarning: urllib3 (2.2.0) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# wandb: Currently logged in as: v-l (vlvl). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/home/vl/Documents/4A/machine_learning/td1_rl/mso_3_4-td1/wandb/run-20240206_163642-fe8gvifv</code>
# Syncing run <strong><a href='https://wandb.ai/vlvl/a2c_training/runs/fe8gvifv' target="_blank">sunny-bird-2</a></strong> to <a href='https://wandb.ai/vlvl/a2c_training' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/vlvl/a2c_training' target="_blank">https://wandb.ai/vlvl/a2c_training</a>
#  View run at <a href='https://wandb.ai/vlvl/a2c_training/runs/fe8gvifv' target="_blank">https://wandb.ai/vlvl/a2c_training/runs/fe8gvifv</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/vlvl/a2c_training/runs/fe8gvifv?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
env = gym.make("PandaReachJointsDense-v3")

model = A2C("MultiInputPolicy", env, verbose=1, tensorboard_log='./a2c_pandareach_tensorboard')
model.learn(total_timesteps=5000000, tb_log_name="training_panda_reach")

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# argv[0]=--background_color_red=0.8745098114013672
# argv[1]=--background_color_green=0.21176470816135406
# argv[2]=--background_color_blue=0.1764705926179886
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./a2c_pandareach_tensorboard/training_panda_reach_1
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.5     |
# |    ep_rew_mean        | -11.1    |
# | time/                 |          |
# |    fps                | 466      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -9.95    |
# |    explained_variance | 0.161    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -3.48    |
# |    std                | 1        |
# |    value_loss         | 0.18     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44       |
# |    ep_rew_mean        | -10.6    |
# | time/                 |          |
# |    fps                | 503      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -9.93    |
# |    explained_variance | -36.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.95     |
# |    std                | 1        |
# |    value_loss         | 0.0514   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.9     |
# |    ep_rew_mean        | -10.7    |
# | time/                 |          |
# |    fps                | 508      |
# |    iterations         | 300      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -9.94    |
# |    explained_variance | 0.716    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -3.01    |
# |    std                | 1        |
# |    value_loss         | 0.068    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 45.2     |
# |    ep_rew_mean        | -11      |
# | time/                 |          |
# |    fps                | 514      |
# |    iterations         | 400      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -9.93    |
# |    explained_variance | -1.15    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -3.17    |
# |    std                | 1        |
# |    value_loss         | 0.114    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.5     |
# |    ep_rew_mean        | -10.9    |
# | time/                 |          |
# |    fps                | 520      |
# |    iterations         | 500      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -9.94    |
# |    explained_variance | -0.638   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.11     |
# |    std                | 1        |
# |    value_loss         | 0.0266   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.7     |
# |    ep_rew_mean        | -10.7    |
# | time/                 |          |
# |    fps                | 518      |
# |    iterations         | 600      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -9.94    |
# |    explained_variance | -0.386   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -7.23    |
# |    std                | 1        |
# |    value_loss         | 0.6      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.3     |
# |    ep_rew_mean        | -10.4    |
# | time/                 |          |
# |    fps                | 520      |
# |    iterations         | 700      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -9.92    |
# |    explained_variance | -2.59    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -2.21    |
# |    std                | 0.999    |
# |    value_loss         | 0.0812   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.6     |
# |    ep_rew_mean        | -10.2    |
# | time/                 |          |
# |    fps                | 520      |
# |    iterations         | 800      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -9.95    |
# |    explained_variance | -713     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.864    |
# |    std                | 1        |
# |    value_loss         | 0.0475   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.1     |
# |    ep_rew_mean        | -10      |
# | time/                 |          |
# |    fps                | 527      |
# |    iterations         | 900      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -9.95    |
# |    explained_variance | 0.305    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.54    |
# |    std                | 1        |
# |    value_loss         | 0.00847  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.3     |
# |    ep_rew_mean        | -9.97    |
# | time/                 |          |
# |    fps                | 528      |
# |    iterations         | 1000     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -9.95    |
# |    explained_variance | -4.58    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 2.06     |
# |    std                | 1        |
# |    value_loss         | 0.142    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.7     |
# |    ep_rew_mean        | -10      |
# | time/                 |          |
# |    fps                | 533      |
# |    iterations         | 1100     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -9.96    |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.825    |
# |    std                | 1        |
# |    value_loss         | 0.00984  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 45.1     |
# |    ep_rew_mean        | -10      |
# | time/                 |          |
# |    fps                | 533      |
# |    iterations         | 1200     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -9.93    |
# |    explained_variance | 0.781    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.707    |
# |    std                | 1        |
# |    value_loss         | 0.0147   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 45       |
# |    ep_rew_mean        | -9.81    |
# | time/                 |          |
# |    fps                | 539      |
# |    iterations         | 1300     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -9.94    |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.212   |
# |    std                | 1        |
# |    value_loss         | 0.0167   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 45.8     |
# |    ep_rew_mean        | -9.77    |
# | time/                 |          |
# |    fps                | 540      |
# |    iterations         | 1400     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -9.91    |
# |    explained_variance | -0.0487  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.395    |
# |    std                | 0.997    |
# |    value_loss         | 0.00489  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.8     |
# |    ep_rew_mean        | -9.44    |
# | time/                 |          |
# |    fps                | 539      |
# |    iterations         | 1500     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -9.93    |
# |    explained_variance | -0.277   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 1.56     |
# |    std                | 1        |
# |    value_loss         | 0.0298   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.1     |
# |    ep_rew_mean        | -9.15    |
# | time/                 |          |
# |    fps                | 539      |
# |    iterations         | 1600     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -9.92    |
# |    explained_variance | -5.42    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -1.14    |
# |    std                | 0.999    |
# |    value_loss         | 0.0438   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.9     |
# |    ep_rew_mean        | -9.08    |
# | time/                 |          |
# |    fps                | 540      |
# |    iterations         | 1700     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -9.92    |
# |    explained_variance | -65.9    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -1.94    |
# |    std                | 0.998    |
# |    value_loss         | 0.0632   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44       |
# |    ep_rew_mean        | -8.69    |
# | time/                 |          |
# |    fps                | 543      |
# |    iterations         | 1800     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -9.94    |
# |    explained_variance | -0.656   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.538    |
# |    std                | 1        |
# |    value_loss         | 0.0109   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.1     |
# |    ep_rew_mean        | -8.49    |
# | time/                 |          |
# |    fps                | 543      |
# |    iterations         | 1900     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -9.93    |
# |    explained_variance | -3.94    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.0336  |
# |    std                | 1        |
# |    value_loss         | 0.0193   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42.7     |
# |    ep_rew_mean        | -7.91    |
# | time/                 |          |
# |    fps                | 544      |
# |    iterations         | 2000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -9.92    |
# |    explained_variance | -3.74    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.986   |
# |    std                | 0.998    |
# |    value_loss         | 0.0113   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.9     |
# |    ep_rew_mean        | -7.54    |
# | time/                 |          |
# |    fps                | 547      |
# |    iterations         | 2100     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -9.91    |
# |    explained_variance | -0.822   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -1.54    |
# |    std                | 0.997    |
# |    value_loss         | 0.0585   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.4     |
# |    ep_rew_mean        | -7.29    |
# | time/                 |          |
# |    fps                | 547      |
# |    iterations         | 2200     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -9.87    |
# |    explained_variance | -9.25    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.981   |
# |    std                | 0.991    |
# |    value_loss         | 0.0164   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.5     |
# |    ep_rew_mean        | -7.17    |
# | time/                 |          |
# |    fps                | 548      |
# |    iterations         | 2300     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -9.84    |
# |    explained_variance | 0.333    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 3.02     |
# |    std                | 0.986    |
# |    value_loss         | 0.106    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.8     |
# |    ep_rew_mean        | -7.25    |
# | time/                 |          |
# |    fps                | 549      |
# |    iterations         | 2400     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -9.85    |
# |    explained_variance | -3.5     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.115   |
# |    std                | 0.989    |
# |    value_loss         | 0.00456  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42.3     |
# |    ep_rew_mean        | -7.26    |
# | time/                 |          |
# |    fps                | 550      |
# |    iterations         | 2500     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -9.85    |
# |    explained_variance | -4.19    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -2.5     |
# |    std                | 0.989    |
# |    value_loss         | 0.104    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.6     |
# |    ep_rew_mean        | -7.09    |
# | time/                 |          |
# |    fps                | 551      |
# |    iterations         | 2600     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -9.83    |
# |    explained_variance | -55.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.613    |
# |    std                | 0.986    |
# |    value_loss         | 0.00847  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.9     |
# |    ep_rew_mean        | -7.13    |
# | time/                 |          |
# |    fps                | 550      |
# |    iterations         | 2700     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -9.84    |
# |    explained_variance | 0.97     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.935    |
# |    std                | 0.987    |
# |    value_loss         | 0.0374   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.2     |
# |    ep_rew_mean        | -7.15    |
# | time/                 |          |
# |    fps                | 552      |
# |    iterations         | 2800     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -9.85    |
# |    explained_variance | -37.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.222    |
# |    std                | 0.988    |
# |    value_loss         | 0.00387  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42       |
# |    ep_rew_mean        | -7.18    |
# | time/                 |          |
# |    fps                | 553      |
# |    iterations         | 2900     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -9.83    |
# |    explained_variance | -2.06    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -0.494   |
# |    std                | 0.986    |
# |    value_loss         | 0.0045   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42       |
# |    ep_rew_mean        | -7.18    |
# | time/                 |          |
# |    fps                | 554      |
# |    iterations         | 3000     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -9.81    |
# |    explained_variance | -1.77    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.506    |
# |    std                | 0.983    |
# |    value_loss         | 0.0087   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.6     |
# |    ep_rew_mean        | -7.07    |
# | time/                 |          |
# |    fps                | 555      |
# |    iterations         | 3100     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -9.77    |
# |    explained_variance | -9.31    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -1.28    |
# |    std                | 0.978    |
# |    value_loss         | 0.0184   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.5     |
# |    ep_rew_mean        | -6.78    |
# | time/                 |          |
# |    fps                | 556      |
# |    iterations         | 3200     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -9.75    |
# |    explained_variance | -0.918   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.854    |
# |    std                | 0.976    |
# |    value_loss         | 0.0131   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.9     |
# |    ep_rew_mean        | -6.72    |
# | time/                 |          |
# |    fps                | 558      |
# |    iterations         | 3300     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -9.77    |
# |    explained_variance | -1.02    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 1.93     |
# |    std                | 0.977    |
# |    value_loss         | 0.0487   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.1     |
# |    ep_rew_mean        | -6.61    |
# | time/                 |          |
# |    fps                | 560      |
# |    iterations         | 3400     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -9.78    |
# |    explained_variance | 0.479    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 1.52     |
# |    std                | 0.979    |
# |    value_loss         | 0.0317   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 39.4     |
# |    ep_rew_mean        | -6.21    |
# | time/                 |          |
# |    fps                | 561      |
# |    iterations         | 3500     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -9.76    |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -1.04    |
# |    std                | 0.976    |
# |    value_loss         | 0.0156   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 38.9     |
# |    ep_rew_mean        | -5.93    |
# | time/                 |          |
# |    fps                | 561      |
# |    iterations         | 3600     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -9.75    |
# |    explained_variance | 0.329    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -1.31    |
# |    std                | 0.975    |
# |    value_loss         | 0.0128   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 37.8     |
# |    ep_rew_mean        | -5.7     |
# | time/                 |          |
# |    fps                | 561      |
# |    iterations         | 3700     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -9.75    |
# |    explained_variance | -0.381   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 3.05     |
# |    std                | 0.975    |
# |    value_loss         | 0.13     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 37.5     |
# |    ep_rew_mean        | -5.62    |
# | time/                 |          |
# |    fps                | 561      |
# |    iterations         | 3800     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -9.74    |
# |    explained_variance | -23.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.707    |
# |    std                | 0.973    |
# |    value_loss         | 0.018    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 38.1     |
# |    ep_rew_mean        | -5.62    |
# | time/                 |          |
# |    fps                | 561      |
# |    iterations         | 3900     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -9.75    |
# |    explained_variance | -0.617   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 1.36     |
# |    std                | 0.974    |
# |    value_loss         | 0.0358   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 37.1     |
# |    ep_rew_mean        | -5.27    |
# | time/                 |          |
# |    fps                | 562      |
# |    iterations         | 4000     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -9.71    |
# |    explained_variance | 0.209    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -3.74    |
# |    std                | 0.969    |
# |    value_loss         | 0.172    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 35.8     |
# |    ep_rew_mean        | -5.01    |
# | time/                 |          |
# |    fps                | 561      |
# |    iterations         | 4100     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -9.71    |
# |    explained_variance | -31.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.766    |
# |    std                | 0.969    |
# |    value_loss         | 0.00897  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 36       |
# |    ep_rew_mean        | -5.05    |
# | time/                 |          |
# |    fps                | 562      |
# |    iterations         | 4200     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -9.71    |
# |    explained_variance | 0.215    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 1.28     |
# |    std                | 0.969    |
# |    value_loss         | 0.0175   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 33.8     |
# |    ep_rew_mean        | -4.63    |
# | time/                 |          |
# |    fps                | 563      |
# |    iterations         | 4300     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -9.73    |
# |    explained_variance | 0.178    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 123      |
# |    std                | 0.972    |
# |    value_loss         | 139      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 31.1     |
# |    ep_rew_mean        | -4.11    |
# | time/                 |          |
# |    fps                | 563      |
# |    iterations         | 4400     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -9.76    |
# |    explained_variance | -0.0112  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 24.8     |
# |    std                | 0.976    |
# |    value_loss         | 36.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | -3.88    |
# | time/                 |          |
# |    fps                | 562      |
# |    iterations         | 4500     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -9.72    |
# |    explained_variance | -0.125   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -1.36    |
# |    std                | 0.971    |
# |    value_loss         | 0.0322   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30.5     |
# |    ep_rew_mean        | -3.94    |
# | time/                 |          |
# |    fps                | 562      |
# |    iterations         | 4600     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -9.76    |
# |    explained_variance | -0.628   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.938   |
# |    std                | 0.976    |
# |    value_loss         | 0.00792  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.6     |
# |    ep_rew_mean        | -3.7     |
# | time/                 |          |
# |    fps                | 562      |
# |    iterations         | 4700     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -9.75    |
# |    explained_variance | 0.727    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -1.6     |
# |    std                | 0.975    |
# |    value_loss         | 0.0289   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.6     |
# |    ep_rew_mean        | -3.63    |
# | time/                 |          |
# |    fps                | 562      |
# |    iterations         | 4800     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -9.73    |
# |    explained_variance | -0.711   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.868    |
# |    std                | 0.972    |
# |    value_loss         | 0.0101   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30.9     |
# |    ep_rew_mean        | -3.8     |
# | time/                 |          |
# |    fps                | 562      |
# |    iterations         | 4900     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -9.7     |
# |    explained_variance | -4.02    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.655    |
# |    std                | 0.969    |
# |    value_loss         | 0.00676  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 31       |
# |    ep_rew_mean        | -3.76    |
# | time/                 |          |
# |    fps                | 561      |
# |    iterations         | 5000     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -9.73    |
# |    explained_variance | -0.0368  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -1.35    |
# |    std                | 0.972    |
# |    value_loss         | 0.0199   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 31       |
# |    ep_rew_mean        | -3.67    |
# | time/                 |          |
# |    fps                | 560      |
# |    iterations         | 5100     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -9.74    |
# |    explained_variance | -12.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.597    |
# |    std                | 0.974    |
# |    value_loss         | 0.00527  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 32.3     |
# |    ep_rew_mean        | -3.79    |
# | time/                 |          |
# |    fps                | 558      |
# |    iterations         | 5200     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -9.74    |
# |    explained_variance | -49.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.595    |
# |    std                | 0.974    |
# |    value_loss         | 0.00679  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30.4     |
# |    ep_rew_mean        | -3.51    |
# | time/                 |          |
# |    fps                | 556      |
# |    iterations         | 5300     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -9.75    |
# |    explained_variance | -0.117   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.692    |
# |    std                | 0.975    |
# |    value_loss         | 0.00745  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.8     |
# |    ep_rew_mean        | -3.43    |
# | time/                 |          |
# |    fps                | 556      |
# |    iterations         | 5400     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -9.71    |
# |    explained_variance | 0.17     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 72.7     |
# |    std                | 0.97     |
# |    value_loss         | 92.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.2     |
# |    ep_rew_mean        | -2.92    |
# | time/                 |          |
# |    fps                | 556      |
# |    iterations         | 5500     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -9.68    |
# |    explained_variance | -0.636   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.933    |
# |    std                | 0.965    |
# |    value_loss         | 0.0117   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.5     |
# |    ep_rew_mean        | -2.83    |
# | time/                 |          |
# |    fps                | 556      |
# |    iterations         | 5600     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -9.67    |
# |    explained_variance | -0.159   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.381   |
# |    std                | 0.965    |
# |    value_loss         | 0.0047   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.8     |
# |    ep_rew_mean        | -2.47    |
# | time/                 |          |
# |    fps                | 553      |
# |    iterations         | 5700     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -9.65    |
# |    explained_variance | -4.3     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.733    |
# |    std                | 0.961    |
# |    value_loss         | 0.0118   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.6     |
# |    ep_rew_mean        | -2.61    |
# | time/                 |          |
# |    fps                | 551      |
# |    iterations         | 5800     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -9.66    |
# |    explained_variance | -0.391   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 57.1     |
# |    std                | 0.963    |
# |    value_loss         | 70.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.2     |
# |    ep_rew_mean        | -2.72    |
# | time/                 |          |
# |    fps                | 548      |
# |    iterations         | 5900     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -9.64    |
# |    explained_variance | -3.23    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 1.04     |
# |    std                | 0.961    |
# |    value_loss         | 0.0119   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.5     |
# |    ep_rew_mean        | -2.59    |
# | time/                 |          |
# |    fps                | 548      |
# |    iterations         | 6000     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -9.65    |
# |    explained_variance | -14.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 1.53     |
# |    std                | 0.962    |
# |    value_loss         | 0.0251   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.8     |
# |    ep_rew_mean        | -2.69    |
# | time/                 |          |
# |    fps                | 548      |
# |    iterations         | 6100     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -9.65    |
# |    explained_variance | 0.208    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.946   |
# |    std                | 0.961    |
# |    value_loss         | 0.0146   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.4     |
# |    ep_rew_mean        | -2.78    |
# | time/                 |          |
# |    fps                | 547      |
# |    iterations         | 6200     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -9.64    |
# |    explained_variance | 0.286    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | 49.7     |
# |    std                | 0.961    |
# |    value_loss         | 38.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.3     |
# |    ep_rew_mean        | -2.78    |
# | time/                 |          |
# |    fps                | 547      |
# |    iterations         | 6300     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -9.64    |
# |    explained_variance | -54.1    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.164    |
# |    std                | 0.961    |
# |    value_loss         | 0.00267  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.8     |
# |    ep_rew_mean        | -2.73    |
# | time/                 |          |
# |    fps                | 546      |
# |    iterations         | 6400     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -9.66    |
# |    explained_variance | -0.162   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 41.9     |
# |    std                | 0.963    |
# |    value_loss         | 44.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.6     |
# |    ep_rew_mean        | -3.16    |
# | time/                 |          |
# |    fps                | 545      |
# |    iterations         | 6500     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -9.63    |
# |    explained_variance | -5.41    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.00172 |
# |    std                | 0.959    |
# |    value_loss         | 0.0068   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.1     |
# |    ep_rew_mean        | -3.52    |
# | time/                 |          |
# |    fps                | 544      |
# |    iterations         | 6600     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -9.63    |
# |    explained_variance | 0.425    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | 44.8     |
# |    std                | 0.96     |
# |    value_loss         | 35.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 27.3     |
# |    ep_rew_mean        | -3.4     |
# | time/                 |          |
# |    fps                | 544      |
# |    iterations         | 6700     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -9.61    |
# |    explained_variance | -0.25    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.544   |
# |    std                | 0.957    |
# |    value_loss         | 0.00759  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.5     |
# |    ep_rew_mean        | -2.98    |
# | time/                 |          |
# |    fps                | 542      |
# |    iterations         | 6800     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -9.57    |
# |    explained_variance | -2.67    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -1.81    |
# |    std                | 0.95     |
# |    value_loss         | 0.0252   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.5     |
# |    ep_rew_mean        | -3.18    |
# | time/                 |          |
# |    fps                | 540      |
# |    iterations         | 6900     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -9.54    |
# |    explained_variance | 0.379    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.636   |
# |    std                | 0.947    |
# |    value_loss         | 0.00925  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.5     |
# |    ep_rew_mean        | -2.48    |
# | time/                 |          |
# |    fps                | 538      |
# |    iterations         | 7000     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -9.51    |
# |    explained_variance | 0.639    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -1.72    |
# |    std                | 0.943    |
# |    value_loss         | 0.0288   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20.4     |
# |    ep_rew_mean        | -2.12    |
# | time/                 |          |
# |    fps                | 535      |
# |    iterations         | 7100     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -9.47    |
# |    explained_variance | -86.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | 0.168    |
# |    std                | 0.938    |
# |    value_loss         | 0.00168  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.4     |
# |    ep_rew_mean        | -2.21    |
# | time/                 |          |
# |    fps                | 535      |
# |    iterations         | 7200     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# ...
# | rollout/              |          |
# |    ep_len_mean        | 11.4     |
# |    ep_rew_mean        | -0.953   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 139900   |
# |    time_elapsed       | 1748     |
# |    total_timesteps    | 699500   |
# | train/                |          |
# |    entropy_loss       | -3.61    |
# |    explained_variance | -553     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 139899   |
# |    policy_loss        | 7.25     |
# |    std                | 0.461    |
# |    value_loss         | 14.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 9.62     |
# |    ep_rew_mean        | -0.779   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 140000   |
# |    time_elapsed       | 1749     |
# |    total_timesteps    | 700000   |
# | train/                |          |
# |    entropy_loss       | -3.57    |
# |    explained_variance | -7.06    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 139999   |
# |    policy_loss        | 0.39     |
# |    std                | 0.458    |
# |    value_loss         | 0.0322   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 9.42     |
# |    ep_rew_mean        | -0.776   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 140100   |
# |    time_elapsed       | 1750     |
# |    total_timesteps    | 700500   |
# | train/                |          |
# |    entropy_loss       | -3.52    |
# |    explained_variance | 0.642    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 140099   |
# |    policy_loss        | -2.96    |
# |    std                | 0.455    |
# |    value_loss         | 0.94     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7.95     |
# |    ep_rew_mean        | -0.653   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 140200   |
# |    time_elapsed       | 1751     |
# |    total_timesteps    | 701000   |
# | train/                |          |
# |    entropy_loss       | -3.5     |
# |    explained_variance | 0.462    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 140199   |
# |    policy_loss        | -1.06    |
# |    std                | 0.453    |
# |    value_loss         | 0.0876   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.51     |
# |    ep_rew_mean        | -0.542   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 140300   |
# |    time_elapsed       | 1752     |
# |    total_timesteps    | 701500   |
# | train/                |          |
# |    entropy_loss       | -3.49    |
# |    explained_variance | 0.857    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 140299   |
# |    policy_loss        | -2.83    |
# |    std                | 0.453    |
# |    value_loss         | 0.815    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.12     |
# |    ep_rew_mean        | -0.487   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 140400   |
# |    time_elapsed       | 1753     |
# |    total_timesteps    | 702000   |
# | train/                |          |
# |    entropy_loss       | -3.46    |
# |    explained_variance | 0.988    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 140399   |
# |    policy_loss        | -0.0819  |
# |    std                | 0.45     |
# |    value_loss         | 0.00146  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.06     |
# |    ep_rew_mean        | -0.506   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 140500   |
# |    time_elapsed       | 1754     |
# |    total_timesteps    | 702500   |
# | train/                |          |
# |    entropy_loss       | -3.45    |
# |    explained_variance | 0.539    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 140499   |
# |    policy_loss        | -1.74    |
# |    std                | 0.449    |
# |    value_loss         | 0.294    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.98     |
# |    ep_rew_mean        | -0.492   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 140600   |
# |    time_elapsed       | 1755     |
# |    total_timesteps    | 703000   |
# | train/                |          |
# |    entropy_loss       | -3.43    |
# |    explained_variance | 0.934    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 140599   |
# |    policy_loss        | -0.665   |
# |    std                | 0.449    |
# |    value_loss         | 0.0379   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.75     |
# |    ep_rew_mean        | -0.477   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 140700   |
# |    time_elapsed       | 1756     |
# |    total_timesteps    | 703500   |
# | train/                |          |
# |    entropy_loss       | -3.43    |
# |    explained_variance | 0.602    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 140699   |
# |    policy_loss        | -0.302   |
# |    std                | 0.448    |
# |    value_loss         | 0.00746  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.57     |
# |    ep_rew_mean        | -0.468   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 140800   |
# |    time_elapsed       | 1757     |
# |    total_timesteps    | 704000   |
# | train/                |          |
# |    entropy_loss       | -3.42    |
# |    explained_variance | 0.927    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 140799   |
# |    policy_loss        | 0.256    |
# |    std                | 0.448    |
# |    value_loss         | 0.00509  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.24     |
# |    ep_rew_mean        | -0.438   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 140900   |
# |    time_elapsed       | 1759     |
# |    total_timesteps    | 704500   |
# | train/                |          |
# |    entropy_loss       | -3.44    |
# |    explained_variance | 0.419    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 140899   |
# |    policy_loss        | -0.484   |
# |    std                | 0.448    |
# |    value_loss         | 0.0319   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.07     |
# |    ep_rew_mean        | -0.423   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 141000   |
# |    time_elapsed       | 1760     |
# |    total_timesteps    | 705000   |
# | train/                |          |
# |    entropy_loss       | -3.44    |
# |    explained_variance | 0.843    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 140999   |
# |    policy_loss        | -0.0165  |
# |    std                | 0.449    |
# |    value_loss         | 0.0142   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.99     |
# |    ep_rew_mean        | -0.418   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 141100   |
# |    time_elapsed       | 1761     |
# |    total_timesteps    | 705500   |
# | train/                |          |
# |    entropy_loss       | -3.44    |
# |    explained_variance | 0.868    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 141099   |
# |    policy_loss        | -0.457   |
# |    std                | 0.449    |
# |    value_loss         | 0.0122   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.08     |
# |    ep_rew_mean        | -0.422   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 141200   |
# |    time_elapsed       | 1762     |
# |    total_timesteps    | 706000   |
# | train/                |          |
# |    entropy_loss       | -3.45    |
# |    explained_variance | 0.673    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 141199   |
# |    policy_loss        | -0.18    |
# |    std                | 0.45     |
# |    value_loss         | 0.0124   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 5.45     |
# |    ep_rew_mean        | -0.446   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 141300   |
# |    time_elapsed       | 1763     |
# |    total_timesteps    | 706500   |
# | train/                |          |
# |    entropy_loss       | -3.47    |
# |    explained_variance | -0.0954  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 141299   |
# |    policy_loss        | -0.149   |
# |    std                | 0.452    |
# |    value_loss         | 0.0202   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.74     |
# |    ep_rew_mean        | -0.557   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 141400   |
# |    time_elapsed       | 1764     |
# |    total_timesteps    | 707000   |
# | train/                |          |
# |    entropy_loss       | -3.46    |
# |    explained_variance | 0.961    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 141399   |
# |    policy_loss        | -0.303   |
# |    std                | 0.451    |
# |    value_loss         | 0.0112   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.83     |
# |    ep_rew_mean        | -0.549   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 141500   |
# |    time_elapsed       | 1765     |
# |    total_timesteps    | 707500   |
# | train/                |          |
# |    entropy_loss       | -3.46    |
# |    explained_variance | -0.648   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 141499   |
# |    policy_loss        | -0.777   |
# |    std                | 0.45     |
# |    value_loss         | 0.043    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 7        |
# |    ep_rew_mean        | -0.574   |
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 141600   |
# |    time_elapsed       | 1767     |
# |    total_timesteps    | 708000   |
# | train/                |          |
# |    entropy_loss       | -3.43    |
# |    explained_variance | 0.958    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 141599   |
# |    policy_loss        | 0.191    |
# |    std                | 0.449    |
# |    value_loss         | 0.0029   |
# ------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 env = gym.make("PandaReachJointsDense-v3")
#       3 model = A2C("MultiInputPolicy", env, verbose=1, tensorboard_log='./a2c_pandareach_tensorboard')
# ----> 4 model.learn(total_timesteps=5000000, tb_log_name="training_panda_reach")
#       6 vec_env = model.get_env()
#       7 obs = vec_env.reset()
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/a2c/a2c.py:201, in A2C.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     192 def learn(
#     193     self: SelfA2C,
#     194     total_timesteps: int,
#    (...)
#     199     progress_bar: bool = False,
#     200 ) -> SelfA2C:
# --> 201     return super().learn(
#     202         total_timesteps=total_timesteps,
#     203         callback=callback,
#     204         log_interval=log_interval,
#     205         tb_log_name=tb_log_name,
#     206         reset_num_timesteps=reset_num_timesteps,
#     207         progress_bar=progress_bar,
#     208     )
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:277, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     274 assert self.env is not None
#     276 while self.num_timesteps < total_timesteps:
# --> 277     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     279     if not continue_training:
#     280         break
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:194, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     189     else:
#     190         # Otherwise, clip the actions to avoid out of bound error
#     191         # as we are sampling from an unbounded Gaussian distribution
#     192         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 194 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     196 self.num_timesteps += env.num_envs
#     198 # Give access to local variables
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:72, in DummyVecEnv.step_wait(self)
#      70         obs, self.reset_infos[env_idx] = self.envs[env_idx].reset()
#      71     self._save_obs(env_idx, obs)
# ---> 72 return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# File /usr/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /usr/lib/python3.10/copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# File /usr/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /usr/lib/python3.10/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File /usr/lib/python3.10/copy.py:142, in deepcopy(x, memo, _nil)
#     139 if y is not _nil:
#     140     return y
# --> 142 cls = type(x)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
#
# KeyboardInterrupt:

# %%
model.save("trained_a2c/a2c_pandareach")
