# %%
import torch 
import gymnasium as gym
from stable_baselines3 import A2C
import wandb
import tensorboard
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:87: RequestsDependencyWarning: urllib3 (2.2.0) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
wandb.init(project="a2c_training", sync_tensorboard=True)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# /usr/lib/python3/dist-packages/requests/__init__.py:87: RequestsDependencyWarning: urllib3 (2.2.0) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# wandb: Currently logged in as: v-l (vlvl). Use `wandb login --relogin` to force relogin
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01111276787778479, max=1.0)…
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/home/vl/Documents/4A/machine_learning/td1_rl/mso_3_4-td1/wandb/run-20240206_160931-x2washva</code>
# Syncing run <strong><a href='https://wandb.ai/vlvl/a2c_training/runs/x2washva' target="_blank">amber-grass-1</a></strong> to <a href='https://wandb.ai/vlvl/a2c_training' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/vlvl/a2c_training' target="_blank">https://wandb.ai/vlvl/a2c_training</a>
#  View run at <a href='https://wandb.ai/vlvl/a2c_training/runs/x2washva' target="_blank">https://wandb.ai/vlvl/a2c_training/runs/x2washva</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/vlvl/a2c_training/runs/x2washva?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")

model = A2C("MlpPolicy", env, verbose=1, tensorboard_log='./a2c_cartpole_tensorboard')
model.learn(total_timesteps=25000, tb_log_name="training")

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./a2c_cartpole_tensorboard/training_2
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 13.2     |
# |    ep_rew_mean        | 13.2     |
# | time/                 |          |
# |    fps                | 1192     |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.612   |
# |    explained_variance | 0.143    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 2.05     |
# |    value_loss         | 9.28     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 12.4     |
# |    ep_rew_mean        | 12.4     |
# | time/                 |          |
# |    fps                | 1131     |
# |    iterations         | 200      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.554   |
# |    explained_variance | 0.193    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.628   |
# |    value_loss         | 47.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 13.5     |
# |    ep_rew_mean        | 13.5     |
# | time/                 |          |
# |    fps                | 1199     |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0.376    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 1.9      |
# |    value_loss         | 8.31     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 15.2     |
# |    ep_rew_mean        | 15.2     |
# | time/                 |          |
# |    fps                | 1169     |
# |    iterations         | 400      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | -0.00219 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 1.56     |
# |    value_loss         | 6.7      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 18.2     |
# |    ep_rew_mean        | 18.2     |
# | time/                 |          |
# |    fps                | 1185     |
# |    iterations         | 500      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | 0.0105   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.34     |
# |    value_loss         | 6.06     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22       |
# |    ep_rew_mean        | 22       |
# | time/                 |          |
# |    fps                | 1206     |
# |    iterations         | 600      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | 0.00458  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.19     |
# |    value_loss         | 5.05     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.7     |
# |    ep_rew_mean        | 26.7     |
# | time/                 |          |
# |    fps                | 1229     |
# |    iterations         | 700      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.619   |
# |    explained_variance | 0.000342 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.92     |
# |    value_loss         | 4.77     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30.1     |
# |    ep_rew_mean        | 30.1     |
# | time/                 |          |
# |    fps                | 1240     |
# |    iterations         | 800      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.645   |
# |    explained_variance | 0.000396 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.871    |
# |    value_loss         | 4.18     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 35.7     |
# |    ep_rew_mean        | 35.7     |
# | time/                 |          |
# |    fps                | 1178     |
# |    iterations         | 900      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.607   |
# |    explained_variance | -0.0249  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.672    |
# |    value_loss         | 3.59     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 39.6     |
# |    ep_rew_mean        | 39.6     |
# | time/                 |          |
# |    fps                | 1166     |
# |    iterations         | 1000     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.627   |
# |    explained_variance | 2.5e-05  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.991    |
# |    value_loss         | 3.15     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.7     |
# |    ep_rew_mean        | 43.7     |
# | time/                 |          |
# |    fps                | 1184     |
# |    iterations         | 1100     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.659   |
# |    explained_variance | 0.00562  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.886    |
# |    value_loss         | 2.73     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47.2     |
# |    ep_rew_mean        | 47.2     |
# | time/                 |          |
# |    fps                | 1195     |
# |    iterations         | 1200     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.661   |
# |    explained_variance | 0.00128  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.75     |
# |    value_loss         | 2.32     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 51.2      |
# |    ep_rew_mean        | 51.2      |
# | time/                 |           |
# |    fps                | 1201      |
# |    iterations         | 1300      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.665    |
# |    explained_variance | -0.000444 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 0.682     |
# |    value_loss         | 1.94      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 55.5     |
# |    ep_rew_mean        | 55.5     |
# | time/                 |          |
# |    fps                | 1213     |
# |    iterations         | 1400     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.65    |
# |    explained_variance | 0.000226 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.662    |
# |    value_loss         | 1.58     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 59.4     |
# |    ep_rew_mean        | 59.4     |
# | time/                 |          |
# |    fps                | 1220     |
# |    iterations         | 1500     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.351   |
# |    explained_variance | 0.000737 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.841    |
# |    value_loss         | 1.26     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 63.5      |
# |    ep_rew_mean        | 63.5      |
# | time/                 |           |
# |    fps                | 1226      |
# |    iterations         | 1600      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.572    |
# |    explained_variance | -0.000445 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 0.351     |
# |    value_loss         | 0.965     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 68.4     |
# |    ep_rew_mean        | 68.4     |
# | time/                 |          |
# |    fps                | 1222     |
# |    iterations         | 1700     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.49    |
# |    explained_variance | 0.000122 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.341    |
# |    value_loss         | 0.71     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 71.8     |
# |    ep_rew_mean        | 71.8     |
# | time/                 |          |
# |    fps                | 1230     |
# |    iterations         | 1800     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.586   |
# |    explained_variance | 0.000167 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.248    |
# |    value_loss         | 0.494    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 76.6     |
# |    ep_rew_mean        | 76.6     |
# | time/                 |          |
# |    fps                | 1234     |
# |    iterations         | 1900     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.613   |
# |    explained_variance | 7.09e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.303    |
# |    value_loss         | 0.331    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 80.6      |
# |    ep_rew_mean        | 80.6      |
# | time/                 |           |
# |    fps                | 1239      |
# |    iterations         | 2000      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.606    |
# |    explained_variance | -6.91e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 0.139     |
# |    value_loss         | 0.195     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 83.9      |
# |    ep_rew_mean        | 83.9      |
# | time/                 |           |
# |    fps                | 1240      |
# |    iterations         | 2100      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.598    |
# |    explained_variance | -0.000365 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | 0.0879    |
# |    value_loss         | 0.0945    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 88.6     |
# |    ep_rew_mean        | 88.6     |
# | time/                 |          |
# |    fps                | 1238     |
# |    iterations         | 2200     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.621   |
# |    explained_variance | 6.56e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.0704   |
# |    value_loss         | 0.0281   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 90.2      |
# |    ep_rew_mean        | 90.2      |
# | time/                 |           |
# |    fps                | 1243      |
# |    iterations         | 2300      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -0.644    |
# |    explained_variance | -0.000146 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | 0.0165    |
# |    value_loss         | 0.00124   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.9     |
# |    ep_rew_mean        | 95.9     |
# | time/                 |          |
# |    fps                | 1248     |
# |    iterations         | 2400     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.573   |
# |    explained_variance | 6.85e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.00177  |
# |    value_loss         | 1.67e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 99.6     |
# |    ep_rew_mean        | 99.6     |
# | time/                 |          |
# |    fps                | 1251     |
# |    iterations         | 2500     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.61    |
# |    explained_variance | 0.000138 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.000496 |
# |    value_loss         | 9.47e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 105      |
# |    ep_rew_mean        | 105      |
# | time/                 |          |
# |    fps                | 1251     |
# |    iterations         | 2600     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.489   |
# |    explained_variance | 0.0093   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.000757 |
# |    value_loss         | 1.19e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 108      |
# |    ep_rew_mean        | 108      |
# | time/                 |          |
# |    fps                | 1254     |
# |    iterations         | 2700     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.58    |
# |    explained_variance | -0.154   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 7.66e-05 |
# |    value_loss         | 6.7e-08  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 112      |
# |    ep_rew_mean        | 112      |
# | time/                 |          |
# |    fps                | 1254     |
# |    iterations         | 2800     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.508   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 4.67e-07 |
# |    value_loss         | 2.33e-11 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 118      |
# |    ep_rew_mean        | 118      |
# | time/                 |          |
# |    fps                | 1258     |
# |    iterations         | 2900     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.543   |
# |    explained_variance | -0.0113  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 7.73e-05 |
# |    value_loss         | 1.64e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 122      |
# |    ep_rew_mean        | 122      |
# | time/                 |          |
# |    fps                | 1256     |
# |    iterations         | 3000     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.566   |
# |    explained_variance | -2.52    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 1.33e-05 |
# |    value_loss         | 1.59e-09 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 125      |
# |    ep_rew_mean        | 125      |
# | time/                 |          |
# |    fps                | 1257     |
# |    iterations         | 3100     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.543   |
# |    explained_variance | 3.95e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.00152  |
# |    value_loss         | 2e-05    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 125      |
# |    ep_rew_mean        | 125      |
# | time/                 |          |
# |    fps                | 1261     |
# |    iterations         | 3200     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.577   |
# |    explained_variance | 0.0279   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.00152  |
# |    value_loss         | 8.34e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 127      |
# |    ep_rew_mean        | 127      |
# | time/                 |          |
# |    fps                | 1258     |
# |    iterations         | 3300     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.591   |
# |    explained_variance | -0.0138  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.000325 |
# |    value_loss         | 7.4e-07  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 129       |
# |    ep_rew_mean        | 129       |
# | time/                 |           |
# |    fps                | 1261      |
# |    iterations         | 3400      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -0.609    |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -8.28e-07 |
# |    value_loss         | 5.82e-11  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 133      |
# |    ep_rew_mean        | 133      |
# | time/                 |          |
# |    fps                | 1264     |
# |    iterations         | 3500     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.514   |
# |    explained_variance | -0.105   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 4.73e-05 |
# |    value_loss         | 7.11e-09 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 136       |
# |    ep_rew_mean        | 136       |
# | time/                 |           |
# |    fps                | 1267      |
# |    iterations         | 3600      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.575    |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -1.39e-05 |
# |    value_loss         | 4.54e-10  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 140       |
# |    ep_rew_mean        | 140       |
# | time/                 |           |
# |    fps                | 1268      |
# |    iterations         | 3700      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -0.602    |
# |    explained_variance | -11.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -3.98e-05 |
# |    value_loss         | 7.23e-09  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 142      |
# |    ep_rew_mean        | 142      |
# | time/                 |          |
# |    fps                | 1270     |
# |    iterations         | 3800     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.507   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 4.57e-07 |
# |    value_loss         | 8.15e-11 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 146      |
# |    ep_rew_mean        | 146      |
# | time/                 |          |
# |    fps                | 1273     |
# |    iterations         | 3900     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.513   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 5.23e-07 |
# |    value_loss         | 1.28e-10 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 151      |
# |    ep_rew_mean        | 151      |
# | time/                 |          |
# |    fps                | 1276     |
# |    iterations         | 4000     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.337   |
# |    explained_variance | -0.72    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 3.11e-05 |
# |    value_loss         | 1.94e-09 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 154      |
# |    ep_rew_mean        | 154      |
# | time/                 |          |
# |    fps                | 1274     |
# |    iterations         | 4100     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.528   |
# |    explained_variance | -0.00111 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.000113 |
# |    value_loss         | 1.01e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 158      |
# |    ep_rew_mean        | 158      |
# | time/                 |          |
# |    fps                | 1272     |
# |    iterations         | 4200     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.538   |
# |    explained_variance | 0.0298   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.000124 |
# |    value_loss         | 1.13e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 160      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 1270     |
# |    iterations         | 4300     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.464   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 1.07e-06 |
# |    value_loss         | 8.15e-11 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 165      |
# |    ep_rew_mean        | 165      |
# | time/                 |          |
# |    fps                | 1271     |
# |    iterations         | 4400     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.401   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0       |
# |    value_loss         | 2.33e-11 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 170       |
# |    ep_rew_mean        | 170       |
# | time/                 |           |
# |    fps                | 1273      |
# |    iterations         | 4500      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.613    |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -2.47e-06 |
# |    value_loss         | 5.82e-11  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 175       |
# |    ep_rew_mean        | 175       |
# | time/                 |           |
# |    fps                | 1276      |
# |    iterations         | 4600      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -0.63     |
# |    explained_variance | -0.000155 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | 0.000688  |
# |    value_loss         | 3.04e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 180       |
# |    ep_rew_mean        | 180       |
# | time/                 |           |
# |    fps                | 1276      |
# |    iterations         | 4700      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -0.611    |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | -7.71e-07 |
# |    value_loss         | 2.33e-11  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 185      |
# |    ep_rew_mean        | 185      |
# | time/                 |          |
# |    fps                | 1278     |
# |    iterations         | 4800     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.539   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 4.99e-07 |
# |    value_loss         | 5.82e-11 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 187       |
# |    ep_rew_mean        | 187       |
# | time/                 |           |
# |    fps                | 1271      |
# |    iterations         | 4900      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -0.335    |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -3.17e-09 |
# |    value_loss         | 6.98e-11  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 191      |
# | time/                 |          |
# |    fps                | 1272     |
# |    iterations         | 5000     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.521   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 6.58e-07 |
# |    value_loss         | 8.15e-11 |
# ------------------------------------
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/vl/.local/lib/python3.10/site-packages/cv2/qt/plugins"
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
